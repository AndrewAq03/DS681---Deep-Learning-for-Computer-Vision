# %%
# !pip install anomalib==2.2.0 torch torchvision pytorch-lightning torchmetrics opencv-python
# Out:
# Collecting anomalib==2.2.0
#   Downloading anomalib-2.2.0-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.5.5-py3-none-any.whl.metadata (20 kB)
# Collecting torchmetrics
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (0.17.0)
# Requirement already satisfied: einops>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (0.8.1)
# Collecting freia>=0.2 (from anomalib==2.2.0)
#   Downloading FrEIA-0.2.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Collecting imagecodecs (from anomalib==2.2.0)
#   Downloading imagecodecs-2025.8.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting jsonargparse>=4.27.7 (from jsonargparse[signatures]>=4.27.7->anomalib==2.2.0)
#   Downloading jsonargparse-4.41.0-py3-none-any.whl.metadata (12 kB)
# Collecting kornia>=0.6.6 (from anomalib==2.2.0)
#   Downloading kornia-0.8.1-py2.py3-none-any.whl.metadata (17 kB)
# Collecting lightning-utilities (from anomalib==2.2.0)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting lightning>=2.2 (from anomalib==2.2.0)
#   Downloading lightning-2.5.5-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: matplotlib>=3.4.3 in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (3.10.0)
# Requirement already satisfied: omegaconf>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (2.3.0)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (2.2.2)
# Requirement already satisfied: pillow>=10.1.0 in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (11.3.0)
# Collecting rich-argparse (from anomalib==2.2.0)
#   Downloading rich_argparse-1.7.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: rich>=13.5.2 in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (13.9.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (1.6.1)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (2025.10.4)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from anomalib==2.2.0) (1.0.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning) (6.0.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning) (25.0)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from freia>=0.2->anomalib==2.2.0) (1.16.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.13.0)
# Collecting typeshed-client>=2.8.2 (from jsonargparse[signatures]>=4.27.7->anomalib==2.2.0)
#   Downloading typeshed_client-2.8.2-py3-none-any.whl.metadata (9.9 kB)
# Collecting kornia_rs>=0.1.9 (from kornia>=0.6.6->anomalib==2.2.0)
#   Downloading kornia_rs-0.1.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib==2.2.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib==2.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib==2.2.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib==2.2.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib==2.2.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib==2.2.0) (2.9.0.post0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.1.1->anomalib==2.2.0) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->anomalib==2.2.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->anomalib==2.2.0) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.5.2->anomalib==2.2.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.5.2->anomalib==2.2.0) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->anomalib==2.2.0) (2.37.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->anomalib==2.2.0) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->anomalib==2.2.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->anomalib==2.2.0) (3.6.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm->anomalib==2.2.0) (0.35.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->anomalib==2.2.0) (0.6.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.22.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.2->anomalib==2.2.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.3->anomalib==2.2.0) (1.17.0)
# Requirement already satisfied: importlib_resources>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from typeshed-client>=2.8.2->jsonargparse[signatures]>=4.27.7->anomalib==2.2.0) (6.5.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->anomalib==2.2.0) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->anomalib==2.2.0) (1.1.10)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib==2.2.0) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib==2.2.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib==2.2.0) (2025.10.5)
# Downloading anomalib-2.2.0-py3-none-any.whl (851 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 851.8/851.8 kB 20.3 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.5-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 58.4 MB/s eta 0:00:00
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 69.6 MB/s eta 0:00:00
# Downloading jsonargparse-4.41.0-py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.5/228.5 kB 10.6 MB/s eta 0:00:00
# Downloading kornia-0.8.1-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 61.9 MB/s eta 0:00:00
# Downloading lightning-2.5.5-py3-none-any.whl (828 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.5/828.5 kB 62.3 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading imagecodecs-2025.8.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 59.1 MB/s eta 0:00:00
# Downloading rich_argparse-1.7.1-py3-none-any.whl (25 kB)
# Downloading kornia_rs-0.1.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 107.6 MB/s eta 0:00:00
# Downloading typeshed_client-2.8.2-py3-none-any.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.5/760.5 kB 55.6 MB/s eta 0:00:00
# Building wheels for collected packages: freia
#   Building wheel for freia (setup.py) ... done
#   Created wheel for freia: filename=FrEIA-0.2-py3-none-any.whl size=42763 sha256=ec8735a9a73208569a6b98caf0d2e23c861dc8ebcef53a71d8d9559b7fab14a9
#   Stored in directory: /root/.cache/pip/wheels/ae/40/63/f30f17a00a5c53f982c5c222995b53fe1ee510d2ea13b00856
# Successfully built freia
# Installing collected packages: typeshed-client, lightning-utilities, kornia_rs, jsonargparse, imagecodecs, rich-argparse, torchmetrics, kornia, freia, pytorch-lightning, lightning, anomalib
# Successfully installed anomalib-2.2.0 freia-0.2 imagecodecs-2025.8.2 jsonargparse-4.41.0 kornia-0.8.1 kornia_rs-0.1.9 lightning-2.5.5 lightning-utilities-0.15.2 pytorch-lightning-2.5.5 rich-argparse-1.7.1 torchmetrics-1.8.2 typeshed-client-2.8.2

# %%
from anomalib.data import MVTecAD
from anomalib.models import Patchcore
from anomalib.engine import Engine
import torch

if torch.cuda.is_available():
    print("GPU is available!")
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available.")

categories = ["grid", "leather", "tile"]
results = {}
# Out:
# GPU is available!
# GPU Name: NVIDIA A100-SXM4-40GB

# %%
# for category in categories:
#     print(f"\n{'='*60}\nProcessing category: {category}\n{'='*60}")

#     # this will load the MVTech module
#     mvt_module = MVTecAD(
#         root="datasets/MVTecAD",
#         category=category,
#         train_batch_size=32,
#         eval_batch_size=32,
#         num_workers=4,
#     )

#     # preprossors point which is the image size and cropped size
#     preprocessor = Patchcore.configure_pre_processor(
#         image_size=(256, 256),
#         center_crop_size=(224, 224)
#     )

#     # this is the pretrained model
#     patchcore_model = Patchcore(
#         backbone="wide_resnet50_2",
#         layers=["layer2", "layer3"],
#         coreset_sampling_ratio=0.1,
#         pre_trained=True,
#         pre_processor=preprocessor
#     )

#     # initialize the engine
#     engine = Engine()

#     # this will train the model
#     engine.fit(model= patchcore_model , datamodule= mvt_module )

#     # and this will test the model
#     metrics = engine.test(model= patchcore_model , datamodule= mvt_module)

#     # we know need to extract the AUROC metrics which is in a dictonary within a list
#     metrics = metrics[0]
#     image_auroc = metrics["image_AUROC"]
#     pixel_auroc = metrics["pixel_AUROC"]
#     results[category] = {"image_AUROC": image_auroc, "pixel_AUROC": pixel_auroc}

# %%
import os
import pickle

ASSET_DIR = "patchcore_assets"
os.makedirs(ASSET_DIR, exist_ok=True)

for category in categories:
    print(f"\n{'='*60}\nProcessing category: {category}\n{'='*60}")

    # this will load the MVTech module
    mvt_module = MVTecAD(
        root="datasets/MVTecAD",
        category=category,
        train_batch_size=32,
        eval_batch_size=32,
        num_workers=4,
    )

    # preprossors point which is the image size and cropped size
    preprocessor = Patchcore.configure_pre_processor(
        image_size=(256, 256),
        center_crop_size=(224, 224)
    )

    # this is the pretrained model
    patchcore_model = Patchcore(
        backbone="wide_resnet50_2",
        layers=["layer2", "layer3"],
        coreset_sampling_ratio=0.1,
        pre_trained=True,
        pre_processor=preprocessor
    )

    # initialize the engine
    engine = Engine()

    # this will train the model
    engine.fit(model= patchcore_model , datamodule= mvt_module )


    memory_bank = patchcore_model.model.memory_bank.data
    memory_bank_path = os.path.join(ASSET_DIR, f"{category}_memory_bank.pt")
    torch.save(memory_bank, memory_bank_path)
    print(f"Saved memory bank for {category} to {memory_bank_path}")
    preprocessor_config = {
        "image_size": (256, 256),
        "center_crop_size": (224, 224),
    }
    with open(os.path.join(ASSET_DIR, f"{category}_preprocessor_config.pkl"), 'wb') as f:
        pickle.dump(preprocessor_config, f)


    # and this will test the model
    metrics = engine.test(model= patchcore_model , datamodule= mvt_module)

    # we know need to extract the AUROC metrics which is in a dictonary within a list
    metrics = metrics[0]
    image_auroc = metrics["image_AUROC"]
    pixel_auroc = metrics["pixel_AUROC"]
    results[category] = {"image_AUROC": image_auroc, "pixel_AUROC": pixel_auroc}
# Out:
# ============================================================
# Processing category: grid
# ============================================================
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:210: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
# INFO:lightning_fabric.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:lightning_fabric.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:lightning_fabric.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/core/optimizer.py:183: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# INFO:
#   | Name           | Type           | Params | Mode
# ----------------------------------------------------------
# 0 | pre_processor  | PreProcessor   | 0      | train
# 1 | post_processor | PostProcessor  | 0      | train
# 2 | evaluator      | Evaluator      | 0      | train
# 3 | model          | PatchcoreModel | 24.9 M | train
# ----------------------------------------------------------
# 24.9 M    Trainable params
# 0         Non-trainable params
# 24.9 M    Total params
# 99.450    Total estimated model params size (MB)
# 19        Modules in train mode
# 174       Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name           | Type           | Params | Mode
# ----------------------------------------------------------
# 0 | pre_processor  | PreProcessor   | 0      | train
# 1 | post_processor | PostProcessor  | 0      | train
# 2 | evaluator      | Evaluator      | 0      | train
# 3 | model          | PatchcoreModel | 24.9 M | train
# ----------------------------------------------------------
# 24.9 M    Trainable params
# 0         Non-trainable params
# 24.9 M    Total params
# 99.450    Total estimated model params size (MB)
# 19        Modules in train mode
# 174       Modules in eval mode
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/fit_loop.py:527: Found 174 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Selecting Coreset Indices.:   0%|          | 0/20697 [00:00<?, ?it/s]
#
# Selecting Coreset Indices.:   1%|          | 137/20697 [00:00<00:15, 1364.64it/s]
#
# Selecting Coreset Indices.:   1%|▏         | 282/20697 [00:00<00:14, 1411.82it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 428/20697 [00:00<00:14, 1431.51it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 573/20697 [00:00<00:14, 1436.06it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 718/20697 [00:00<00:13, 1438.00it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 864/20697 [00:00<00:13, 1443.80it/s]
#
# Selecting Coreset Indices.:   5%|▍         | 1009/20697 [00:00<00:13, 1436.95it/s]
#
# Selecting Coreset Indices.:   6%|▌         | 1153/20697 [00:00<00:13, 1435.86it/s]
#
# Selecting Coreset Indices.:   6%|▋         | 1298/20697 [00:00<00:13, 1437.51it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1443/20697 [00:01<00:13, 1440.06it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1588/20697 [00:01<00:13, 1442.48it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1733/20697 [00:01<00:13, 1439.28it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1881/20697 [00:01<00:12, 1450.00it/s]
#
# Selecting Coreset Indices.:  10%|▉         | 2029/20697 [00:01<00:12, 1456.34it/s]
#
# Selecting Coreset Indices.:  11%|█         | 2177/20697 [00:01<00:12, 1461.98it/s]
#
# Selecting Coreset Indices.:  11%|█         | 2325/20697 [00:01<00:12, 1466.23it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2472/20697 [00:01<00:12, 1464.45it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2619/20697 [00:01<00:12, 1461.01it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2766/20697 [00:01<00:12, 1462.51it/s]
#
# Selecting Coreset Indices.:  14%|█▍        | 2913/20697 [00:02<00:12, 1464.53it/s]
#
# Selecting Coreset Indices.:  15%|█▍        | 3061/20697 [00:02<00:12, 1466.82it/s]
#
# Selecting Coreset Indices.:  15%|█▌        | 3208/20697 [00:02<00:11, 1466.24it/s]
#
# Selecting Coreset Indices.:  16%|█▌        | 3356/20697 [00:02<00:11, 1468.43it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3504/20697 [00:02<00:11, 1470.85it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3653/20697 [00:02<00:11, 1473.99it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3801/20697 [00:02<00:11, 1468.80it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3948/20697 [00:02<00:11, 1463.60it/s]
#
# Selecting Coreset Indices.:  20%|█▉        | 4096/20697 [00:02<00:11, 1465.94it/s]
#
# Selecting Coreset Indices.:  21%|██        | 4243/20697 [00:02<00:11, 1464.48it/s]
#
# Selecting Coreset Indices.:  21%|██        | 4391/20697 [00:03<00:11, 1467.27it/s]
#
# Selecting Coreset Indices.:  22%|██▏       | 4539/20697 [00:03<00:10, 1470.14it/s]
#
# Selecting Coreset Indices.:  23%|██▎       | 4687/20697 [00:03<00:10, 1469.94it/s]
#
# Selecting Coreset Indices.:  23%|██▎       | 4835/20697 [00:03<00:10, 1470.37it/s]
#
# Selecting Coreset Indices.:  24%|██▍       | 4983/20697 [00:03<00:10, 1471.75it/s]
#
# Selecting Coreset Indices.:  25%|██▍       | 5131/20697 [00:03<00:10, 1472.82it/s]
#
# Selecting Coreset Indices.:  26%|██▌       | 5279/20697 [00:03<00:10, 1468.88it/s]
#
# Selecting Coreset Indices.:  26%|██▌       | 5426/20697 [00:03<00:10, 1468.98it/s]
#
# Selecting Coreset Indices.:  27%|██▋       | 5573/20697 [00:03<00:10, 1466.85it/s]
#
# Selecting Coreset Indices.:  28%|██▊       | 5720/20697 [00:03<00:10, 1466.91it/s]
#
# Selecting Coreset Indices.:  28%|██▊       | 5867/20697 [00:04<00:10, 1466.57it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 6015/20697 [00:04<00:09, 1468.35it/s]
#
# Selecting Coreset Indices.:  30%|██▉       | 6163/20697 [00:04<00:09, 1470.32it/s]
#
# Selecting Coreset Indices.:  30%|███       | 6311/20697 [00:04<00:09, 1471.76it/s]
#
# Selecting Coreset Indices.:  31%|███       | 6459/20697 [00:04<00:09, 1471.26it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 6607/20697 [00:04<00:09, 1472.44it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 6755/20697 [00:04<00:09, 1471.80it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 6903/20697 [00:04<00:09, 1468.03it/s]
#
# Selecting Coreset Indices.:  34%|███▍      | 7051/20697 [00:04<00:09, 1468.70it/s]
#
# Selecting Coreset Indices.:  35%|███▍      | 7198/20697 [00:04<00:09, 1468.35it/s]
#
# Selecting Coreset Indices.:  35%|███▌      | 7346/20697 [00:05<00:09, 1469.41it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 7494/20697 [00:05<00:08, 1470.94it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 7642/20697 [00:05<00:08, 1472.95it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 7790/20697 [00:05<00:08, 1471.90it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 7938/20697 [00:05<00:08, 1470.97it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 8086/20697 [00:05<00:08, 1468.55it/s]
#
# Selecting Coreset Indices.:  40%|███▉      | 8233/20697 [00:05<00:08, 1465.16it/s]
#
# Selecting Coreset Indices.:  40%|████      | 8380/20697 [00:05<00:08, 1462.43it/s]
#
# Selecting Coreset Indices.:  41%|████      | 8528/20697 [00:05<00:08, 1465.41it/s]
#
# Selecting Coreset Indices.:  42%|████▏     | 8676/20697 [00:05<00:08, 1468.39it/s]
#
# Selecting Coreset Indices.:  43%|████▎     | 8824/20697 [00:06<00:08, 1471.54it/s]
#
# Selecting Coreset Indices.:  43%|████▎     | 8972/20697 [00:06<00:07, 1472.28it/s]
#
# Selecting Coreset Indices.:  44%|████▍     | 9120/20697 [00:06<00:07, 1472.97it/s]
#
# Selecting Coreset Indices.:  45%|████▍     | 9268/20697 [00:06<00:07, 1474.38it/s]
#
# Selecting Coreset Indices.:  45%|████▌     | 9416/20697 [00:06<00:07, 1473.97it/s]
#
# Selecting Coreset Indices.:  46%|████▌     | 9564/20697 [00:06<00:07, 1474.90it/s]
#
# Selecting Coreset Indices.:  47%|████▋     | 9712/20697 [00:06<00:07, 1474.50it/s]
#
# Selecting Coreset Indices.:  48%|████▊     | 9860/20697 [00:06<00:07, 1471.91it/s]
#
# Selecting Coreset Indices.:  48%|████▊     | 10008/20697 [00:06<00:07, 1472.97it/s]
#
# Selecting Coreset Indices.:  49%|████▉     | 10156/20697 [00:06<00:07, 1471.96it/s]
#
# Selecting Coreset Indices.:  50%|████▉     | 10304/20697 [00:07<00:07, 1473.03it/s]
#
# Selecting Coreset Indices.:  51%|█████     | 10452/20697 [00:07<00:06, 1473.40it/s]
#
# Selecting Coreset Indices.:  51%|█████     | 10600/20697 [00:07<00:06, 1472.56it/s]
#
# Selecting Coreset Indices.:  52%|█████▏    | 10748/20697 [00:07<00:06, 1472.02it/s]
#
# Selecting Coreset Indices.:  53%|█████▎    | 10896/20697 [00:07<00:06, 1471.83it/s]
#
# Selecting Coreset Indices.:  53%|█████▎    | 11044/20697 [00:07<00:06, 1472.52it/s]
#
# Selecting Coreset Indices.:  54%|█████▍    | 11192/20697 [00:07<00:06, 1468.19it/s]
#
# Selecting Coreset Indices.:  55%|█████▍    | 11339/20697 [00:07<00:06, 1463.94it/s]
#
# Selecting Coreset Indices.:  55%|█████▌    | 11486/20697 [00:07<00:06, 1460.30it/s]
#
# Selecting Coreset Indices.:  56%|█████▌    | 11633/20697 [00:07<00:06, 1461.94it/s]
#
# Selecting Coreset Indices.:  57%|█████▋    | 11780/20697 [00:08<00:06, 1461.74it/s]
#
# Selecting Coreset Indices.:  58%|█████▊    | 11927/20697 [00:08<00:05, 1462.60it/s]
#
# Selecting Coreset Indices.:  58%|█████▊    | 12074/20697 [00:08<00:05, 1463.96it/s]
#
# Selecting Coreset Indices.:  59%|█████▉    | 12221/20697 [00:08<00:05, 1463.88it/s]
#
# Selecting Coreset Indices.:  60%|█████▉    | 12368/20697 [00:08<00:05, 1462.41it/s]
#
# Selecting Coreset Indices.:  60%|██████    | 12516/20697 [00:08<00:05, 1465.71it/s]
#
# Selecting Coreset Indices.:  61%|██████    | 12663/20697 [00:08<00:05, 1465.03it/s]
#
# Selecting Coreset Indices.:  62%|██████▏   | 12811/20697 [00:08<00:05, 1469.10it/s]
#
# Selecting Coreset Indices.:  63%|██████▎   | 12958/20697 [00:08<00:05, 1466.74it/s]
#
# Selecting Coreset Indices.:  63%|██████▎   | 13106/20697 [00:08<00:05, 1468.09it/s]
#
# Selecting Coreset Indices.:  64%|██████▍   | 13253/20697 [00:09<00:05, 1467.11it/s]
#
# Selecting Coreset Indices.:  65%|██████▍   | 13400/20697 [00:09<00:04, 1460.05it/s]
#
# Selecting Coreset Indices.:  65%|██████▌   | 13547/20697 [00:09<00:04, 1455.17it/s]
#
# Selecting Coreset Indices.:  66%|██████▌   | 13693/20697 [00:09<00:04, 1449.91it/s]
#
# Selecting Coreset Indices.:  67%|██████▋   | 13838/20697 [00:09<00:04, 1448.61it/s]
#
# Selecting Coreset Indices.:  68%|██████▊   | 13985/20697 [00:09<00:04, 1454.46it/s]
#
# Selecting Coreset Indices.:  68%|██████▊   | 14132/20697 [00:09<00:04, 1457.32it/s]
#
# Selecting Coreset Indices.:  69%|██████▉   | 14279/20697 [00:09<00:04, 1459.37it/s]
#
# Selecting Coreset Indices.:  70%|██████▉   | 14426/20697 [00:09<00:04, 1460.02it/s]
#
# Selecting Coreset Indices.:  70%|███████   | 14574/20697 [00:09<00:04, 1463.14it/s]
#
# Selecting Coreset Indices.:  71%|███████   | 14721/20697 [00:10<00:04, 1463.80it/s]
#
# Selecting Coreset Indices.:  72%|███████▏  | 14868/20697 [00:10<00:03, 1463.70it/s]
#
# Selecting Coreset Indices.:  73%|███████▎  | 15015/20697 [00:10<00:03, 1464.25it/s]
#
# Selecting Coreset Indices.:  73%|███████▎  | 15163/20697 [00:10<00:03, 1467.52it/s]
#
# Selecting Coreset Indices.:  74%|███████▍  | 15310/20697 [00:10<00:03, 1467.12it/s]
#
# Selecting Coreset Indices.:  75%|███████▍  | 15458/20697 [00:10<00:03, 1468.26it/s]
#
# Selecting Coreset Indices.:  75%|███████▌  | 15605/20697 [00:10<00:03, 1465.88it/s]
#
# Selecting Coreset Indices.:  76%|███████▌  | 15753/20697 [00:10<00:03, 1468.64it/s]
#
# Selecting Coreset Indices.:  77%|███████▋  | 15901/20697 [00:10<00:03, 1470.06it/s]
#
# Selecting Coreset Indices.:  78%|███████▊  | 16049/20697 [00:10<00:03, 1470.47it/s]
#
# Selecting Coreset Indices.:  78%|███████▊  | 16197/20697 [00:11<00:03, 1471.85it/s]
#
# Selecting Coreset Indices.:  79%|███████▉  | 16345/20697 [00:11<00:02, 1472.86it/s]
#
# Selecting Coreset Indices.:  80%|███████▉  | 16493/20697 [00:11<00:02, 1472.00it/s]
#
# Selecting Coreset Indices.:  80%|████████  | 16641/20697 [00:11<00:02, 1471.07it/s]
#
# Selecting Coreset Indices.:  81%|████████  | 16789/20697 [00:11<00:02, 1471.17it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 16937/20697 [00:11<00:02, 1469.33it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 17084/20697 [00:11<00:02, 1469.04it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 17232/20697 [00:11<00:02, 1471.65it/s]
#
# Selecting Coreset Indices.:  84%|████████▍ | 17380/20697 [00:11<00:02, 1469.59it/s]
#
# Selecting Coreset Indices.:  85%|████████▍ | 17527/20697 [00:11<00:02, 1467.60it/s]
#
# Selecting Coreset Indices.:  85%|████████▌ | 17675/20697 [00:12<00:02, 1469.10it/s]
#
# Selecting Coreset Indices.:  86%|████████▌ | 17823/20697 [00:12<00:01, 1469.50it/s]
#
# Selecting Coreset Indices.:  87%|████████▋ | 17970/20697 [00:12<00:01, 1468.14it/s]
#
# Selecting Coreset Indices.:  88%|████████▊ | 18117/20697 [00:12<00:01, 1467.28it/s]
#
# Selecting Coreset Indices.:  88%|████████▊ | 18265/20697 [00:12<00:01, 1469.67it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 18413/20697 [00:12<00:01, 1470.77it/s]
#
# Selecting Coreset Indices.:  90%|████████▉ | 18561/20697 [00:12<00:01, 1472.31it/s]
#
# Selecting Coreset Indices.:  90%|█████████ | 18709/20697 [00:12<00:01, 1471.86it/s]
#
# Selecting Coreset Indices.:  91%|█████████ | 18857/20697 [00:12<00:01, 1471.09it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 19005/20697 [00:12<00:01, 1471.09it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 19153/20697 [00:13<00:01, 1471.96it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 19301/20697 [00:13<00:00, 1470.09it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 19449/20697 [00:13<00:00, 1469.80it/s]
#
# Selecting Coreset Indices.:  95%|█████████▍| 19597/20697 [00:13<00:00, 1470.60it/s]
#
# Selecting Coreset Indices.:  95%|█████████▌| 19745/20697 [00:13<00:00, 1471.94it/s]
#
# Selecting Coreset Indices.:  96%|█████████▌| 19893/20697 [00:13<00:00, 1472.90it/s]
#
# Selecting Coreset Indices.:  97%|█████████▋| 20041/20697 [00:13<00:00, 1473.56it/s]
#
# Selecting Coreset Indices.:  98%|█████████▊| 20189/20697 [00:13<00:00, 1472.49it/s]
#
# Selecting Coreset Indices.:  98%|█████████▊| 20337/20697 [00:13<00:00, 1471.77it/s]
#
# Selecting Coreset Indices.:  99%|█████████▉| 20485/20697 [00:13<00:00, 1472.30it/s]
#
# Selecting Coreset Indices.: 100%|██████████| 20697/20697 [00:14<00:00, 1465.45it/s]
# INFO:lightning_fabric.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.
# Saved memory bank for grid to patchcore_assets/grid_memory_bank.pt
# INFO:lightning_fabric.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │     0.981620728969574     │
# │       image_F1Score       │    0.9557521939277649     │
# │        pixel_AUROC        │    0.9790642261505127     │
# │       pixel_F1Score       │    0.3782416582107544     │
# └───────────────────────────┴───────────────────────────┘
# ============================================================
# Processing category: leather
# ============================================================
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:210: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
# INFO:lightning_fabric.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:lightning_fabric.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:lightning_fabric.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/core/optimizer.py:183: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# INFO:
#   | Name           | Type           | Params | Mode
# ----------------------------------------------------------
# 0 | pre_processor  | PreProcessor   | 0      | train
# 1 | post_processor | PostProcessor  | 0      | train
# 2 | evaluator      | Evaluator      | 0      | train
# 3 | model          | PatchcoreModel | 24.9 M | train
# ----------------------------------------------------------
# 24.9 M    Trainable params
# 0         Non-trainable params
# 24.9 M    Total params
# 99.450    Total estimated model params size (MB)
# 19        Modules in train mode
# 174       Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name           | Type           | Params | Mode
# ----------------------------------------------------------
# 0 | pre_processor  | PreProcessor   | 0      | train
# 1 | post_processor | PostProcessor  | 0      | train
# 2 | evaluator      | Evaluator      | 0      | train
# 3 | model          | PatchcoreModel | 24.9 M | train
# ----------------------------------------------------------
# 24.9 M    Trainable params
# 0         Non-trainable params
# 24.9 M    Total params
# 99.450    Total estimated model params size (MB)
# 19        Modules in train mode
# 174       Modules in eval mode
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/fit_loop.py:527: Found 174 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Selecting Coreset Indices.:   0%|          | 0/19208 [00:00<?, ?it/s]
#
# Selecting Coreset Indices.:   1%|          | 140/19208 [00:00<00:13, 1392.30it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 294/19208 [00:00<00:12, 1474.70it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 449/19208 [00:00<00:12, 1508.51it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 609/19208 [00:00<00:12, 1544.23it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 769/19208 [00:00<00:11, 1562.68it/s]
#
# Selecting Coreset Indices.:   5%|▍         | 926/19208 [00:00<00:11, 1554.93it/s]
#
# Selecting Coreset Indices.:   6%|▌         | 1087/19208 [00:00<00:11, 1570.60it/s]
#
# Selecting Coreset Indices.:   6%|▋         | 1246/19208 [00:00<00:11, 1575.05it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1407/19208 [00:00<00:11, 1583.38it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1567/19208 [00:01<00:11, 1588.23it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1727/19208 [00:01<00:10, 1590.32it/s]
#
# Selecting Coreset Indices.:  10%|▉         | 1887/19208 [00:01<00:10, 1590.71it/s]
#
# Selecting Coreset Indices.:  11%|█         | 2047/19208 [00:01<00:10, 1570.06it/s]
#
# Selecting Coreset Indices.:  11%|█▏        | 2208/19208 [00:01<00:10, 1581.35it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2369/19208 [00:01<00:10, 1587.53it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2528/19208 [00:01<00:10, 1578.20it/s]
#
# Selecting Coreset Indices.:  14%|█▍        | 2690/19208 [00:01<00:10, 1588.13it/s]
#
# Selecting Coreset Indices.:  15%|█▍        | 2852/19208 [00:01<00:10, 1596.71it/s]
#
# Selecting Coreset Indices.:  16%|█▌        | 3012/19208 [00:01<00:10, 1592.69it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3173/19208 [00:02<00:10, 1597.16it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3334/19208 [00:02<00:09, 1600.44it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3496/19208 [00:02<00:09, 1604.51it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3659/19208 [00:02<00:09, 1610.41it/s]
#
# Selecting Coreset Indices.:  20%|█▉        | 3822/19208 [00:02<00:09, 1615.35it/s]
#
# Selecting Coreset Indices.:  21%|██        | 3985/19208 [00:02<00:09, 1619.35it/s]
#
# Selecting Coreset Indices.:  22%|██▏       | 4147/19208 [00:02<00:09, 1616.34it/s]
#
# Selecting Coreset Indices.:  22%|██▏       | 4310/19208 [00:02<00:09, 1619.72it/s]
#
# Selecting Coreset Indices.:  23%|██▎       | 4473/19208 [00:02<00:09, 1620.17it/s]
#
# Selecting Coreset Indices.:  24%|██▍       | 4636/19208 [00:02<00:09, 1613.88it/s]
#
# Selecting Coreset Indices.:  25%|██▍       | 4799/19208 [00:03<00:08, 1617.55it/s]
#
# Selecting Coreset Indices.:  26%|██▌       | 4962/19208 [00:03<00:08, 1620.97it/s]
#
# Selecting Coreset Indices.:  27%|██▋       | 5125/19208 [00:03<00:08, 1621.72it/s]
#
# Selecting Coreset Indices.:  28%|██▊       | 5288/19208 [00:03<00:08, 1623.17it/s]
#
# Selecting Coreset Indices.:  28%|██▊       | 5452/19208 [00:03<00:08, 1625.93it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 5615/19208 [00:03<00:08, 1626.85it/s]
#
# Selecting Coreset Indices.:  30%|███       | 5778/19208 [00:03<00:08, 1624.06it/s]
#
# Selecting Coreset Indices.:  31%|███       | 5941/19208 [00:03<00:08, 1625.76it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 6104/19208 [00:03<00:08, 1623.42it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 6267/19208 [00:03<00:07, 1622.91it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 6430/19208 [00:04<00:07, 1621.19it/s]
#
# Selecting Coreset Indices.:  34%|███▍      | 6593/19208 [00:04<00:07, 1620.03it/s]
#
# Selecting Coreset Indices.:  35%|███▌      | 6756/19208 [00:04<00:07, 1619.99it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 6919/19208 [00:04<00:07, 1620.22it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 7082/19208 [00:04<00:07, 1619.36it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 7245/19208 [00:04<00:07, 1622.47it/s]
#
# Selecting Coreset Indices.:  39%|███▊      | 7409/19208 [00:04<00:07, 1625.18it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 7573/19208 [00:04<00:07, 1628.07it/s]
#
# Selecting Coreset Indices.:  40%|████      | 7737/19208 [00:04<00:07, 1628.86it/s]
#
# Selecting Coreset Indices.:  41%|████      | 7900/19208 [00:04<00:06, 1628.95it/s]
#
# Selecting Coreset Indices.:  42%|████▏     | 8063/19208 [00:05<00:06, 1621.02it/s]
#
# Selecting Coreset Indices.:  43%|████▎     | 8226/19208 [00:05<00:06, 1612.06it/s]
#
# Selecting Coreset Indices.:  44%|████▎     | 8388/19208 [00:05<00:06, 1613.47it/s]
#
# Selecting Coreset Indices.:  45%|████▍     | 8550/19208 [00:05<00:06, 1613.76it/s]
#
# Selecting Coreset Indices.:  45%|████▌     | 8713/19208 [00:05<00:06, 1615.98it/s]
#
# Selecting Coreset Indices.:  46%|████▌     | 8876/19208 [00:05<00:06, 1617.86it/s]
#
# Selecting Coreset Indices.:  47%|████▋     | 9038/19208 [00:05<00:06, 1617.27it/s]
#
# Selecting Coreset Indices.:  48%|████▊     | 9200/19208 [00:05<00:06, 1614.00it/s]
#
# Selecting Coreset Indices.:  49%|████▊     | 9362/19208 [00:05<00:06, 1606.34it/s]
#
# Selecting Coreset Indices.:  50%|████▉     | 9523/19208 [00:05<00:06, 1600.18it/s]
#
# Selecting Coreset Indices.:  50%|█████     | 9684/19208 [00:06<00:05, 1593.48it/s]
#
# Selecting Coreset Indices.:  51%|█████     | 9844/19208 [00:06<00:05, 1594.08it/s]
#
# Selecting Coreset Indices.:  52%|█████▏    | 10006/19208 [00:06<00:05, 1599.79it/s]
#
# Selecting Coreset Indices.:  53%|█████▎    | 10169/19208 [00:06<00:05, 1606.39it/s]
#
# Selecting Coreset Indices.:  54%|█████▍    | 10330/19208 [00:06<00:05, 1606.82it/s]
#
# Selecting Coreset Indices.:  55%|█████▍    | 10492/19208 [00:06<00:05, 1609.85it/s]
#
# Selecting Coreset Indices.:  55%|█████▌    | 10654/19208 [00:06<00:05, 1609.98it/s]
#
# Selecting Coreset Indices.:  56%|█████▋    | 10817/19208 [00:06<00:05, 1613.03it/s]
#
# Selecting Coreset Indices.:  57%|█████▋    | 10979/19208 [00:06<00:05, 1613.18it/s]
#
# Selecting Coreset Indices.:  58%|█████▊    | 11141/19208 [00:06<00:05, 1613.02it/s]
#
# Selecting Coreset Indices.:  59%|█████▉    | 11303/19208 [00:07<00:04, 1612.83it/s]
#
# Selecting Coreset Indices.:  60%|█████▉    | 11465/19208 [00:07<00:04, 1610.68it/s]
#
# Selecting Coreset Indices.:  61%|██████    | 11627/19208 [00:07<00:04, 1609.89it/s]
#
# Selecting Coreset Indices.:  61%|██████▏   | 11790/19208 [00:07<00:04, 1613.48it/s]
#
# Selecting Coreset Indices.:  62%|██████▏   | 11952/19208 [00:07<00:04, 1611.33it/s]
#
# Selecting Coreset Indices.:  63%|██████▎   | 12114/19208 [00:07<00:04, 1611.96it/s]
#
# Selecting Coreset Indices.:  64%|██████▍   | 12277/19208 [00:07<00:04, 1616.24it/s]
#
# Selecting Coreset Indices.:  65%|██████▍   | 12440/19208 [00:07<00:04, 1620.00it/s]
#
# Selecting Coreset Indices.:  66%|██████▌   | 12603/19208 [00:07<00:04, 1620.77it/s]
#
# Selecting Coreset Indices.:  66%|██████▋   | 12766/19208 [00:07<00:03, 1620.45it/s]
#
# Selecting Coreset Indices.:  67%|██████▋   | 12930/19208 [00:08<00:03, 1623.15it/s]
#
# Selecting Coreset Indices.:  68%|██████▊   | 13093/19208 [00:08<00:03, 1624.63it/s]
#
# Selecting Coreset Indices.:  69%|██████▉   | 13256/19208 [00:08<00:03, 1625.57it/s]
#
# Selecting Coreset Indices.:  70%|██████▉   | 13419/19208 [00:08<00:03, 1626.76it/s]
#
# Selecting Coreset Indices.:  71%|███████   | 13583/19208 [00:08<00:03, 1629.44it/s]
#
# Selecting Coreset Indices.:  72%|███████▏  | 13746/19208 [00:08<00:03, 1627.31it/s]
#
# Selecting Coreset Indices.:  72%|███████▏  | 13909/19208 [00:08<00:03, 1625.02it/s]
#
# Selecting Coreset Indices.:  73%|███████▎  | 14072/19208 [00:08<00:03, 1624.21it/s]
#
# Selecting Coreset Indices.:  74%|███████▍  | 14235/19208 [00:08<00:03, 1623.94it/s]
#
# Selecting Coreset Indices.:  75%|███████▍  | 14398/19208 [00:08<00:02, 1621.55it/s]
#
# Selecting Coreset Indices.:  76%|███████▌  | 14561/19208 [00:09<00:02, 1620.23it/s]
#
# Selecting Coreset Indices.:  77%|███████▋  | 14724/19208 [00:09<00:02, 1622.54it/s]
#
# Selecting Coreset Indices.:  78%|███████▊  | 14887/19208 [00:09<00:02, 1618.46it/s]
#
# Selecting Coreset Indices.:  78%|███████▊  | 15051/19208 [00:09<00:02, 1622.32it/s]
#
# Selecting Coreset Indices.:  79%|███████▉  | 15214/19208 [00:09<00:02, 1613.21it/s]
#
# Selecting Coreset Indices.:  80%|████████  | 15376/19208 [00:09<00:02, 1612.21it/s]
#
# Selecting Coreset Indices.:  81%|████████  | 15538/19208 [00:09<00:02, 1611.75it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15700/19208 [00:09<00:02, 1608.06it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 15861/19208 [00:09<00:02, 1605.76it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 16022/19208 [00:09<00:01, 1606.07it/s]
#
# Selecting Coreset Indices.:  84%|████████▍ | 16185/19208 [00:10<00:01, 1610.73it/s]
#
# Selecting Coreset Indices.:  85%|████████▌ | 16349/19208 [00:10<00:01, 1616.82it/s]
#
# Selecting Coreset Indices.:  86%|████████▌ | 16512/19208 [00:10<00:01, 1618.33it/s]
#
# Selecting Coreset Indices.:  87%|████████▋ | 16674/19208 [00:10<00:01, 1617.63it/s]
#
# Selecting Coreset Indices.:  88%|████████▊ | 16836/19208 [00:10<00:01, 1617.44it/s]
#
# Selecting Coreset Indices.:  88%|████████▊ | 16998/19208 [00:10<00:01, 1615.86it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 17160/19208 [00:10<00:01, 1615.76it/s]
#
# Selecting Coreset Indices.:  90%|█████████ | 17322/19208 [00:10<00:01, 1608.30it/s]
#
# Selecting Coreset Indices.:  91%|█████████ | 17483/19208 [00:10<00:01, 1597.54it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17643/19208 [00:10<00:00, 1598.06it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17805/19208 [00:11<00:00, 1603.67it/s]
#
# Selecting Coreset Indices.:  94%|█████████▎| 17969/19208 [00:11<00:00, 1611.66it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 18131/19208 [00:11<00:00, 1613.74it/s]
#
# Selecting Coreset Indices.:  95%|█████████▌| 18294/19208 [00:11<00:00, 1617.01it/s]
#
# Selecting Coreset Indices.:  96%|█████████▌| 18457/19208 [00:11<00:00, 1619.47it/s]
#
# Selecting Coreset Indices.:  97%|█████████▋| 18620/19208 [00:11<00:00, 1622.51it/s]
#
# Selecting Coreset Indices.:  98%|█████████▊| 18783/19208 [00:11<00:00, 1623.76it/s]
#
# Selecting Coreset Indices.:  99%|█████████▊| 18947/19208 [00:11<00:00, 1626.04it/s]
#
# Selecting Coreset Indices.: 100%|██████████| 19208/19208 [00:11<00:00, 1609.63it/s]
# INFO:lightning_fabric.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.
# Saved memory bank for leather to patchcore_assets/leather_memory_bank.pt
# INFO:lightning_fabric.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │            1.0            │
# │       image_F1Score       │     0.994535505771637     │
# │        pixel_AUROC        │    0.9899813532829285     │
# │       pixel_F1Score       │    0.4401886761188507     │
# └───────────────────────────┴───────────────────────────┘
# ============================================================
# Processing category: tile
# ============================================================
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:210: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
# INFO:lightning_fabric.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:lightning_fabric.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:lightning_fabric.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/core/optimizer.py:183: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# INFO:
#   | Name           | Type           | Params | Mode
# ----------------------------------------------------------
# 0 | pre_processor  | PreProcessor   | 0      | train
# 1 | post_processor | PostProcessor  | 0      | train
# 2 | evaluator      | Evaluator      | 0      | train
# 3 | model          | PatchcoreModel | 24.9 M | train
# ----------------------------------------------------------
# 24.9 M    Trainable params
# 0         Non-trainable params
# 24.9 M    Total params
# 99.450    Total estimated model params size (MB)
# 19        Modules in train mode
# 174       Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name           | Type           | Params | Mode
# ----------------------------------------------------------
# 0 | pre_processor  | PreProcessor   | 0      | train
# 1 | post_processor | PostProcessor  | 0      | train
# 2 | evaluator      | Evaluator      | 0      | train
# 3 | model          | PatchcoreModel | 24.9 M | train
# ----------------------------------------------------------
# 24.9 M    Trainable params
# 0         Non-trainable params
# 24.9 M    Total params
# 99.450    Total estimated model params size (MB)
# 19        Modules in train mode
# 174       Modules in eval mode
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/fit_loop.py:527: Found 174 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Selecting Coreset Indices.:   0%|          | 0/18032 [00:00<?, ?it/s]
#
# Selecting Coreset Indices.:   1%|          | 154/18032 [00:00<00:11, 1530.68it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 315/18032 [00:00<00:11, 1572.97it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 476/18032 [00:00<00:11, 1589.20it/s]
#
# Selecting Coreset Indices.:   4%|▎         | 641/18032 [00:00<00:10, 1611.50it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 806/18032 [00:00<00:10, 1625.02it/s]
#
# Selecting Coreset Indices.:   5%|▌         | 969/18032 [00:00<00:10, 1619.96it/s]
#
# Selecting Coreset Indices.:   6%|▋         | 1132/18032 [00:00<00:10, 1615.71it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1298/18032 [00:00<00:10, 1626.62it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1465/18032 [00:00<00:10, 1637.13it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1630/18032 [00:01<00:10, 1638.33it/s]
#
# Selecting Coreset Indices.:  10%|▉         | 1796/18032 [00:01<00:09, 1641.58it/s]
#
# Selecting Coreset Indices.:  11%|█         | 1962/18032 [00:01<00:09, 1644.72it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2128/18032 [00:01<00:09, 1647.98it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2293/18032 [00:01<00:09, 1632.26it/s]
#
# Selecting Coreset Indices.:  14%|█▎        | 2457/18032 [00:01<00:09, 1630.89it/s]
#
# Selecting Coreset Indices.:  15%|█▍        | 2624/18032 [00:01<00:09, 1639.87it/s]
#
# Selecting Coreset Indices.:  15%|█▌        | 2791/18032 [00:01<00:09, 1647.79it/s]
#
# Selecting Coreset Indices.:  16%|█▋        | 2958/18032 [00:01<00:09, 1652.14it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3124/18032 [00:01<00:09, 1653.89it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3291/18032 [00:02<00:08, 1657.83it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3458/18032 [00:02<00:08, 1660.57it/s]
#
# Selecting Coreset Indices.:  20%|██        | 3625/18032 [00:02<00:08, 1662.46it/s]
#
# Selecting Coreset Indices.:  21%|██        | 3792/18032 [00:02<00:08, 1663.82it/s]
#
# Selecting Coreset Indices.:  22%|██▏       | 3959/18032 [00:02<00:08, 1660.17it/s]
#
# Selecting Coreset Indices.:  23%|██▎       | 4126/18032 [00:02<00:08, 1662.49it/s]
#
# Selecting Coreset Indices.:  24%|██▍       | 4293/18032 [00:02<00:08, 1663.09it/s]
#
# Selecting Coreset Indices.:  25%|██▍       | 4460/18032 [00:02<00:08, 1664.98it/s]
#
# Selecting Coreset Indices.:  26%|██▌       | 4627/18032 [00:02<00:08, 1662.86it/s]
#
# Selecting Coreset Indices.:  27%|██▋       | 4794/18032 [00:02<00:07, 1658.90it/s]
#
# Selecting Coreset Indices.:  28%|██▊       | 4960/18032 [00:03<00:07, 1658.93it/s]
#
# Selecting Coreset Indices.:  28%|██▊       | 5126/18032 [00:03<00:07, 1656.65it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 5292/18032 [00:03<00:07, 1654.92it/s]
#
# Selecting Coreset Indices.:  30%|███       | 5459/18032 [00:03<00:07, 1657.34it/s]
#
# Selecting Coreset Indices.:  31%|███       | 5626/18032 [00:03<00:07, 1658.15it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5792/18032 [00:03<00:07, 1657.35it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 5959/18032 [00:03<00:07, 1659.35it/s]
#
# Selecting Coreset Indices.:  34%|███▍      | 6125/18032 [00:03<00:07, 1657.58it/s]
#
# Selecting Coreset Indices.:  35%|███▍      | 6291/18032 [00:03<00:07, 1653.65it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 6457/18032 [00:03<00:07, 1644.79it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6622/18032 [00:04<00:06, 1645.93it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6788/18032 [00:04<00:06, 1648.27it/s]
#
# Selecting Coreset Indices.:  39%|███▊      | 6955/18032 [00:04<00:06, 1653.59it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 7122/18032 [00:04<00:06, 1656.97it/s]
#
# Selecting Coreset Indices.:  40%|████      | 7288/18032 [00:04<00:06, 1657.61it/s]
#
# Selecting Coreset Indices.:  41%|████▏     | 7454/18032 [00:04<00:06, 1655.19it/s]
#
# Selecting Coreset Indices.:  42%|████▏     | 7621/18032 [00:04<00:06, 1657.41it/s]
#
# Selecting Coreset Indices.:  43%|████▎     | 7788/18032 [00:04<00:06, 1659.01it/s]
#
# Selecting Coreset Indices.:  44%|████▍     | 7954/18032 [00:04<00:06, 1658.82it/s]
#
# Selecting Coreset Indices.:  45%|████▌     | 8120/18032 [00:04<00:05, 1654.86it/s]
#
# Selecting Coreset Indices.:  46%|████▌     | 8286/18032 [00:05<00:05, 1651.29it/s]
#
# Selecting Coreset Indices.:  47%|████▋     | 8452/18032 [00:05<00:05, 1651.13it/s]
#
# Selecting Coreset Indices.:  48%|████▊     | 8619/18032 [00:05<00:05, 1655.57it/s]
#
# Selecting Coreset Indices.:  49%|████▊     | 8785/18032 [00:05<00:05, 1654.27it/s]
#
# Selecting Coreset Indices.:  50%|████▉     | 8952/18032 [00:05<00:05, 1657.47it/s]
#
# Selecting Coreset Indices.:  51%|█████     | 9119/18032 [00:05<00:05, 1660.68it/s]
#
# Selecting Coreset Indices.:  51%|█████▏    | 9286/18032 [00:05<00:05, 1661.91it/s]
#
# Selecting Coreset Indices.:  52%|█████▏    | 9453/18032 [00:05<00:05, 1655.31it/s]
#
# Selecting Coreset Indices.:  53%|█████▎    | 9620/18032 [00:05<00:05, 1658.98it/s]
#
# Selecting Coreset Indices.:  54%|█████▍    | 9787/18032 [00:05<00:04, 1661.89it/s]
#
# Selecting Coreset Indices.:  55%|█████▌    | 9954/18032 [00:06<00:04, 1663.58it/s]
#
# Selecting Coreset Indices.:  56%|█████▌    | 10121/18032 [00:06<00:04, 1661.05it/s]
#
# Selecting Coreset Indices.:  57%|█████▋    | 10288/18032 [00:06<00:04, 1663.68it/s]
#
# Selecting Coreset Indices.:  58%|█████▊    | 10455/18032 [00:06<00:04, 1663.80it/s]
#
# Selecting Coreset Indices.:  59%|█████▉    | 10622/18032 [00:06<00:04, 1661.10it/s]
#
# Selecting Coreset Indices.:  60%|█████▉    | 10789/18032 [00:06<00:04, 1658.70it/s]
#
# Selecting Coreset Indices.:  61%|██████    | 10957/18032 [00:06<00:04, 1662.24it/s]
#
# Selecting Coreset Indices.:  62%|██████▏   | 11124/18032 [00:06<00:04, 1662.28it/s]
#
# Selecting Coreset Indices.:  63%|██████▎   | 11292/18032 [00:06<00:04, 1665.64it/s]
#
# Selecting Coreset Indices.:  64%|██████▎   | 11459/18032 [00:06<00:03, 1665.54it/s]
#
# Selecting Coreset Indices.:  64%|██████▍   | 11626/18032 [00:07<00:03, 1664.01it/s]
#
# Selecting Coreset Indices.:  65%|██████▌   | 11793/18032 [00:07<00:03, 1658.68it/s]
#
# Selecting Coreset Indices.:  66%|██████▋   | 11960/18032 [00:07<00:03, 1659.81it/s]
#
# Selecting Coreset Indices.:  67%|██████▋   | 12127/18032 [00:07<00:03, 1662.22it/s]
#
# Selecting Coreset Indices.:  68%|██████▊   | 12294/18032 [00:07<00:03, 1657.80it/s]
#
# Selecting Coreset Indices.:  69%|██████▉   | 12461/18032 [00:07<00:03, 1659.69it/s]
#
# Selecting Coreset Indices.:  70%|███████   | 12628/18032 [00:07<00:03, 1660.16it/s]
#
# Selecting Coreset Indices.:  71%|███████   | 12795/18032 [00:07<00:03, 1654.65it/s]
#
# Selecting Coreset Indices.:  72%|███████▏  | 12962/18032 [00:07<00:03, 1657.90it/s]
#
# Selecting Coreset Indices.:  73%|███████▎  | 13128/18032 [00:07<00:02, 1652.60it/s]
#
# Selecting Coreset Indices.:  74%|███████▎  | 13294/18032 [00:08<00:02, 1646.24it/s]
#
# Selecting Coreset Indices.:  75%|███████▍  | 13459/18032 [00:08<00:02, 1646.97it/s]
#
# Selecting Coreset Indices.:  76%|███████▌  | 13626/18032 [00:08<00:02, 1652.82it/s]
#
# Selecting Coreset Indices.:  76%|███████▋  | 13792/18032 [00:08<00:02, 1654.19it/s]
#
# Selecting Coreset Indices.:  77%|███████▋  | 13960/18032 [00:08<00:02, 1659.42it/s]
#
# Selecting Coreset Indices.:  78%|███████▊  | 14127/18032 [00:08<00:02, 1661.78it/s]
#
# Selecting Coreset Indices.:  79%|███████▉  | 14294/18032 [00:08<00:02, 1659.79it/s]
#
# Selecting Coreset Indices.:  80%|████████  | 14461/18032 [00:08<00:02, 1661.72it/s]
#
# Selecting Coreset Indices.:  81%|████████  | 14628/18032 [00:08<00:02, 1658.67it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 14794/18032 [00:08<00:01, 1654.35it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 14961/18032 [00:09<00:01, 1658.54it/s]
#
# Selecting Coreset Indices.:  84%|████████▍ | 15128/18032 [00:09<00:01, 1659.47it/s]
#
# Selecting Coreset Indices.:  85%|████████▍ | 15294/18032 [00:09<00:01, 1658.87it/s]
#
# Selecting Coreset Indices.:  86%|████████▌ | 15462/18032 [00:09<00:01, 1663.95it/s]
#
# Selecting Coreset Indices.:  87%|████████▋ | 15629/18032 [00:09<00:01, 1664.05it/s]
#
# Selecting Coreset Indices.:  88%|████████▊ | 15797/18032 [00:09<00:01, 1666.17it/s]
#
# Selecting Coreset Indices.:  89%|████████▊ | 15964/18032 [00:09<00:01, 1664.10it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 16132/18032 [00:09<00:01, 1666.30it/s]
#
# Selecting Coreset Indices.:  90%|█████████ | 16299/18032 [00:09<00:01, 1666.68it/s]
#
# Selecting Coreset Indices.:  91%|█████████▏| 16467/18032 [00:09<00:00, 1668.08it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 16634/18032 [00:10<00:00, 1667.05it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 16801/18032 [00:10<00:00, 1665.82it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 16968/18032 [00:10<00:00, 1664.66it/s]
#
# Selecting Coreset Indices.:  95%|█████████▌| 17135/18032 [00:10<00:00, 1665.00it/s]
#
# Selecting Coreset Indices.:  96%|█████████▌| 17302/18032 [00:10<00:00, 1664.05it/s]
#
# Selecting Coreset Indices.:  97%|█████████▋| 17470/18032 [00:10<00:00, 1667.11it/s]
#
# Selecting Coreset Indices.:  98%|█████████▊| 17637/18032 [00:10<00:00, 1667.60it/s]
#
# Selecting Coreset Indices.:  99%|█████████▊| 17804/18032 [00:10<00:00, 1662.57it/s]
#
# Selecting Coreset Indices.: 100%|██████████| 18032/18032 [00:10<00:00, 1654.91it/s]
# INFO:lightning_fabric.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.
# Saved memory bank for tile to patchcore_assets/tile_memory_bank.pt
# INFO:lightning_fabric.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │    0.9859307408332825     │
# │       image_F1Score       │    0.9818181991577148     │
# │        pixel_AUROC        │    0.9477715492248535     │
# │       pixel_F1Score       │    0.6210078001022339     │
# └───────────────────────────┴───────────────────────────┘

# %%
#Showing the AUROC for each catagory type
for cat, vals in results.items():
    print(f"{cat.capitalize()} → Image AUROC: {vals['image_AUROC']:.4f}, Pixel AUROC: {vals['pixel_AUROC']:.4f}")

# The means of Image AUROC and Pixel AUROC
image_mean = torch.tensor([v["image_AUROC"] for v in results.values()]).mean().item()
pixel_mean = torch.tensor([v["pixel_AUROC"] for v in results.values()]).mean().item()

print("\nAverage across flat surfaces:")
print(f"→ Mean Image AUROC: {image_mean:.4f}")
print(f"→ Mean Pixel AUROC: {pixel_mean:.4f}")
# Out:
# Grid → Image AUROC: 0.9774, Pixel AUROC: 0.9796
# Leather → Image AUROC: 1.0000, Pixel AUROC: 0.9900
# Tile → Image AUROC: 0.9877, Pixel AUROC: 0.9477
#
# Average across flat surfaces:
# → Mean Image AUROC: 0.9884
# → Mean Pixel AUROC: 0.9724

# %%
import matplotlib.pyplot as plt

categories = list(results.keys())
image_aurocs = [v["image_AUROC"] for v in results.values()]
pixel_aurocs = [v["pixel_AUROC"] for v in results.values()]

plt.figure(figsize=(8,5))
bar_width = 0.35
x = torch.arange(len(categories))

plt.bar(x - bar_width/2, image_aurocs, width=bar_width, label="Image AUROC")
plt.bar(x + bar_width/2, pixel_aurocs, width=bar_width, label="Pixel AUROC")

plt.axhline(image_mean, color='red', linestyle='--', alpha=0.5, label="Mean Image AUROC")
plt.axhline(pixel_mean, color='green', linestyle='--', alpha=0.5, label="Mean Pixel AUROC")

plt.xticks(x, [c.capitalize() for c in categories])
plt.ylim(0.5, 1.0)
plt.ylabel("AUROC")
plt.title("PatchCore Results on MVTec Categories")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
